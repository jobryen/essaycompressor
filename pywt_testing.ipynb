# %%
# !pip install nbstripout
# !nbstripout --install
#stops notebook output being uploaded to git, reduces noise

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pywt
import pywt.data

cA, cD = pywt.dwt([1, 2, 3, 4], 'db1')

# %%
import os
os.listdir(".")

pywt.wavelist()

# %%
# Load image
path = 'TestPhotos/testfile_11.gif'
original = plt.imread(path)

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
# Load image
path = 'TestPhotos/kodim01.png'
original = np.array(Image.open(path).convert("L"))

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
# Load images
paths = ['TestPhotos/kodim01.png','TestPhotos/kodim02.png','TestPhotos/kodim03.png','TestPhotos/kodim04.png','TestPhotos/testfile_11.gif']

for path in paths:
    original = np.array(Image.open(path).convert("L"))

    # Wavelet transform of image, and plot approximation and details
    titles = ['Approximation', ' Horizontal detail (edges)',
          'Vertical detail (edges)', 'Diagonal detail']
    coeffs2 = pywt.dwt2(original, 'bior1.3')
    LL, (LH, HL, HH) = coeffs2
    fig = plt.figure(figsize=(12, 3))
    for i, a in enumerate([LL, LH, HL, HH]):
        ax = fig.add_subplot(1, 4, i + 1)
        ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
        ax.set_title(titles[i], fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()
    plt.show()

# %%
path = 'TestPhotos/testfile_11.gif'
original = np.array(Image.open(path).convert("L"))

# Wavelet transform of image, and plot approximation and details

for wavelet in pywt.wavelist(kind='discrete'):
    titles = [wavelet, ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
    coeffs2 = pywt.dwt2(original, wavelet)
    LL, (LH, HL, HH) = coeffs2
    fig = plt.figure(figsize=(12, 3))
    for i, a in enumerate([LL, LH, HL, HH]):
        ax = fig.add_subplot(1, 4, i + 1)
        ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
        ax.set_title(titles[i], fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()
    plt.show()
